# %%
import pandas as pd
import os

# %%
# Since the csv file is located in it's parent sub folder.
fileDir = os.path.dirname(os.path.realpath('__file__'))
loc_rel = os.path.join(fileDir, '../datasets/1/summer.csv')
loc_abs = os.path.abspath(os.path.realpath(loc_rel))

# %%
summer_df = pd.read_csv(loc_abs)
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
# Re-Indexing the dataframe.
summer_df_rein = pd.read_csv(loc_rel, index_col='Athlete')
summer_df_rein.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
# Fetching the first row using iloc[] method.
summer_df_rein.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
# Fetching the last row.
summer_df_rein.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
# Updating the index to start from 1 isted of 0 (i.e. default)
summer_df.index = summer_df.index + 1

# %%
# Fetching the first 3 rows.
summer_df.iloc[[0,1,2]]
# Out:
#    Year    City     Sport Discipline            Athlete Country Gender  \
# 1  1896  Athens  Aquatics   Swimming      HAJOS, Alfred     HUN    Men
# 2  1896  Athens  Aquatics   Swimming   HERSCHMANN, Otto     AUT    Men
# 3  1896  Athens  Aquatics   Swimming  DRIVAS, Dimitrios     GRE    Men
#
#                         Event   Medal
# 1              100M Freestyle    Gold
# 2              100M Freestyle  Silver
# 3  100M Freestyle For Sailors  Bronze

# %%
# Resetting the index.
summer_df.index = summer_df.index - 1

# %%
# Other way of fetching the first 3 rows.
summer_df.iloc[0:3]

# In here it starts with first digit but excludes the last postion.
# Out:
#    Year    City     Sport Discipline            Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming      HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming   HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming  DRIVAS, Dimitrios     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze

# %%
# OR
summer_df[:3]
# Out:
#    Year    City     Sport Discipline            Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming      HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming   HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming  DRIVAS, Dimitrios     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze

# %%
# Last 3 rows.
summer_df[-3:]
# Out:
#        Year    City      Sport           Discipline            Athlete  \
# 31162  2012  London  Wrestling  Wrestling Freestyle     TOTROV, Rustam
# 31163  2012  London  Wrestling  Wrestling Freestyle  ALEKSANYAN, Artur
# 31164  2012  London  Wrestling  Wrestling Freestyle     LIDBERG, Jimmy
#
#       Country Gender     Event   Medal
# 31162     RUS    Men  Wg 96 KG  Silver
# 31163     ARM    Men  Wg 96 KG  Bronze
# 31164     SWE    Men  Wg 96 KG  Bronze

# %%
# Lets say we need a specific value from a particular row, first row 5th column.
summer_df.iloc[0,4]
# Out:
# 'HAJOS, Alfred'

# %%
# Lets say we need a specific value from a particular row, first row 2nd to 5th column.
summer_df.iloc[0,2:4]
# Out:
# Sport         Aquatics
# Discipline    Swimming
# Name: 0, dtype: object

# %%
# Lets say we need a specific value from a particular row, first row specific columns.
summer_df.iloc[0,[2,4,6]]
# Out:
# Sport           Aquatics
# Athlete    HAJOS, Alfred
# Gender               Men
# Name: 0, dtype: object

# %%
# Similarly the same operation can also be performed at column level.
summer_df.iloc[[2,4,6],4]
# Out:
# 2     DRIVAS, Dimitrios
# 4    CHASAPIS, Spiridon
# 6         HAJOS, Alfred
# Name: Athlete, dtype: object

# %%
# E.g. we need all the the data related to Michael Phelps.
summer_df.loc[summer_df['Athlete'] == 'PHELPS, Michael']
# Out:
#        Year     City     Sport Discipline          Athlete Country Gender  \
# 25225  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25253  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25258  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25265  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25277  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25286  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25325  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25361  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27224  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27252  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27258  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27264  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27276  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27291  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27327  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27366  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 29270  2012   London  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 29298  2012   London  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 29309  2012   London  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 29340  2012   London  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 29370  2012   London  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 29405  2012   London  Aquatics   Swimming  PHELPS, Michael     USA    Men
#
#                         Event   Medal
# 25225          100M Butterfly    Gold
# 25253          200M Butterfly    Gold
# 25258          200M Freestyle  Bronze
# 25265  200M Individual Medley    Gold
# 25277  400M Individual Medley    Gold
# 25286  4X100M Freestyle Relay  Bronze
# 25325     4X100M Medley Relay    Gold
# 25361  4X200M Freestyle Relay    Gold
# 27224          100M Butterfly    Gold
# 27252          200M Butterfly    Gold
# 27258          200M Freestyle    Gold
# 27264  200M Individual Medley    Gold
# 27276  400M Individual Medley    Gold
# 27291  4X100M Freestyle Relay    Gold
# 27327     4X100M Medley Relay    Gold
# 27366  4X200M Freestyle Relay    Gold
# 29270          100M Butterfly    Gold
# 29298          200M Butterfly  Silver
# 29309             200M Medley    Gold
# 29340        4X100M Freestyle  Silver
# 29370           4X100M Medley    Gold
# 29405        4X200M Freestyle    Gold

# %%
# Let's say we just want Athelete and it's medals.
summer_df.loc[summer_df['Athlete'] == 'PHELPS, Michael',['Athlete','Medal','Event']]
# Out:
#                Athlete   Medal                   Event
# 25225  PHELPS, Michael    Gold          100M Butterfly
# 25253  PHELPS, Michael    Gold          200M Butterfly
# 25258  PHELPS, Michael  Bronze          200M Freestyle
# 25265  PHELPS, Michael    Gold  200M Individual Medley
# 25277  PHELPS, Michael    Gold  400M Individual Medley
# 25286  PHELPS, Michael  Bronze  4X100M Freestyle Relay
# 25325  PHELPS, Michael    Gold     4X100M Medley Relay
# 25361  PHELPS, Michael    Gold  4X200M Freestyle Relay
# 27224  PHELPS, Michael    Gold          100M Butterfly
# 27252  PHELPS, Michael    Gold          200M Butterfly
# 27258  PHELPS, Michael    Gold          200M Freestyle
# 27264  PHELPS, Michael    Gold  200M Individual Medley
# 27276  PHELPS, Michael    Gold  400M Individual Medley
# 27291  PHELPS, Michael    Gold  4X100M Freestyle Relay
# 27327  PHELPS, Michael    Gold     4X100M Medley Relay
# 27366  PHELPS, Michael    Gold  4X200M Freestyle Relay
# 29270  PHELPS, Michael    Gold          100M Butterfly
# 29298  PHELPS, Michael  Silver          200M Butterfly
# 29309  PHELPS, Michael    Gold             200M Medley
# 29340  PHELPS, Michael  Silver        4X100M Freestyle
# 29370  PHELPS, Michael    Gold           4X100M Medley
# 29405  PHELPS, Michael    Gold        4X200M Freestyle

# %%
summer_df.loc[['PHELPS, Michael'],['Athlete','Medal','Event']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-7fc33d7fe4cf> in <module>
# ----> 1 summer_df.loc[['PHELPS, Michael'],['Athlete','Medal','Event']]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1279         # ugly hack for GH #836
#    1280         if self._multi_take_opportunity(tup):
# -> 1281             return self._multi_take(tup)
#    1282
#    1283         # no shortcut needed
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _multi_take(self, tup)
#    1336         # GH 836
#    1337         o = self.obj
# -> 1338         d = {
#    1339             axis: self._get_listlike_indexer(key, axis)
#    1340             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in <dictcomp>(.0)
#    1337         o = self.obj
#    1338         d = {
# -> 1339             axis: self._get_listlike_indexer(key, axis)
#    1340             for (key, axis) in zip(tup, o._AXIS_ORDERS)
#    1341         }
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['PHELPS, Michael'], dtype='object')] are in the [index]"
